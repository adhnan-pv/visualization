# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fmri=pd.read_csv(r"pandas_docs\seaborn\seaborn-data\fmri.csv")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
fmri1=fmri.region.value_counts()

# %%
fmri1
# Out:
# parietal    532
# frontal     532
# Name: region, dtype: int64

# %%
sns.relplot(data=fmri,x='timepoint',y='signal',style='subject',size='region',hue='event',)

# %%
flights=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\flights.csv")

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(data=flights,x='year',y='passengers',kind='line',hue='month')

# %%
plt.bar(flights['year'],flights['passengers'],align='center')
# Out:
# <BarContainer object of 144 artists>

# %% [markdown]
# year by year the number of the passenger are increasing

# %%
taxis=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\taxis.csv")

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
a=taxis['payment'].value_counts()

# %%
taxis['payment'].dropna()
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6433, dtype: object

# %%
taxis['payment'].unique()
# Out:
# array(['credit card', 'cash', 0], dtype=object)

# %%
plt.pie(a,labels=taxis['payment'].unique())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 plt.pie(a,labels=taxis['payment'].unique())
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
tips=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\tips.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='time',size='size')

# %%
plt.hist(tips['total_bill'],color='green')
plt.xlabel('total bill')
plt.ylabel('tip')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 2
#       1 plt.hist(tips['total_bill'],color='green')
# ----> 2 plt.xlabel('total bill')
#       3 plt.ylabel('tip')
#       4 plt.show()
#
# TypeError: 'str' object is not callable

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
da=taxis.filter(items=['distance','tip'])

# %%
da
# Out:
#       distance   tip
# 0         1.60  2.15
# 1         0.79  0.00
# 2         1.37  2.36
# 3         7.70  6.15
# 4         2.16  1.10
# ...        ...   ...
# 6428      0.75  1.06
# 6429     18.74  0.00
# 6430      4.14  0.00
# 6431      1.12  0.00
# 6432      3.85  3.36
#
# [6433 rows x 2 columns]

# %%
plt.plot(

# %%
da=taxis.value_counts('payment')

# %%
da
# Out:
# payment
# credit card    4577
# cash           1812
# dtype: int64

# %%
di=taxis['payment'].unique()

# %%
di
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
taxis['payment'].dropna()
# Out:
# 0       credit card
# 1              cash
# 2       credit card
# 3       credit card
# 4       credit card
#            ...
# 6428    credit card
# 6429    credit card
# 6430           cash
# 6431    credit card
# 6432    credit card
# Name: payment, Length: 6389, dtype: object

# %%
di=taxis['payment'].unique()

# %%
di
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
plt.pie(da,autopct='1%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1f987a12b50>,
# ...
#  [Text(-0.6915026152866067, 0.855467201622472, ''),
#   Text(0.6915026953812236, -0.8554671368793211, '')],
#  [Text(-0.3771832447017855, 0.4666184736122574, '171.6%'),
#   Text(0.37718328838975823, -0.46661843829781147, '128.4%')])
