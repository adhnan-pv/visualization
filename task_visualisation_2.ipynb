# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
titanic=pd.read_csv(r"D:\data analyst\pandas_docs\seaborn\seaborn-data\titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
alive=titanic['alive'].value_counts()

# %%
titanic['alive'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
plt.pie(alive,labels=titanic['alive'].unique(),autopct='1%.1f%%',colors=['#db291d','#24c219'])
plt.show()

# %% [markdown]
#  - 161.6% people were died in the titanic crash
#  - 138.4% people are only alive or survived the crash

# %%
titanic_1=titanic[['survived','age']]

# %%
titanic_1
# Out:
#      survived   age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
titanic_1=titanic['survived'].unique()

# %%
titanic_1
# Out:
# array([0, 1], dtype=int64)

# %%
sns.catplot(data=titanic,x='survived',y='age',kind='swarm',col='sex',sharey=False)

# %% [markdown]
# * 1 indicate survived and 0 indicate the died
# - this show the survived and died people in the ship by their age
# - female are more survived than the male
# - in between the age of 15 to 50 are the most died male
# - in between 20 to 35 aged male are survived the most
# - in between the age of 10 to 50 aged females more survived

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_who=titanic['who'].value_counts()

# %%
titanic_who
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
titanic['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
explode=0.3,0.3,0.3
plt.pie(titanic_who,labels=titanic['who'].unique(),autopct='1%.1f%%',colors=['#d11d26','#1dd123','#074ce0'],explode=explode)
plt.legend()
plt.show()

# %% [markdown]
# - 160.3% are men passengers in the ship
# - 19.3% are child passengers in the ship
# - 130.4% are women passengers

# %%
titanic['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
sns.catplot(data=titanic,x='embark_town',y='age',palette='rocket',hue='who',kind='swarm')
plt.show()

# %% [markdown]
# - most of the passangers embark from southampton
# - least passanger embark from queenstown
# - more childs are from southampton

# %%
sns.catplot(data=titanic,x='embark_town',y='age',palette='rocket',hue='alive',kind='swarm',col='alive')
plt.show()

# %% [markdown]
# - most passangers are died from southampton
# - least passangers died from queenstown
# - most people survived are from southampton
# - only 8 passangers survived from queenstown

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_2=titanic['survived'].value_counts()

# %%
titanic_2
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
titanic['survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
iris=pd.read_csv("D:\data analyst\pandas_docs\seaborn\seaborn-data\iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
